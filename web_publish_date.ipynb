# %% [markdown]
# Importing necessary libraries and modules

# %%
import csv
import pandas as pd
from htmldate import find_date
import matplotlib as plt

# %%
data = pd.read_csv("top500Domains.csv")

# %%
data.head()
# Out:
#    Rank      Root Domain Linking Root Domains  Domain Authority
# 0     1        apple.com            4,606,834               100
# 1     2   www.google.com           12,130,886               100
# 2     3      youtube.com           17,792,956               100
# 3     4    microsoft.com            4,544,029                99
# 4     5  play.google.com            2,383,583                99

# %%
url_list = 'https://' + data['Root Domain']
url_list

def wrapper_find_date(url):
    print(url)
    p = find_date(url)
    print('Found date for url', p)
    return p

# %%
data['Publish Date'] = url_list.apply(wrapper_find_date)
# Out:
# https://apple.com
# Found date for url 2020-01-01
# https://www.google.com
# Found date for url 2020-01-01
# https://youtube.com
# Found date for url 2020-01-01
# https://microsoft.com
# Found date for url 2020-08-04
# https://play.google.com
# Found date for url 2020-07-26
# https://support.google.com
# Found date for url 2020-07-06
# https://docs.google.com
# Found date for url None
# https://www.blogger.com
# Found date for url 2010-05-01
# https://wordpress.org
# Found date for url 2019-01-28
# https://linkedin.com
# Found date for url 2020-01-01
# https://adobe.com
# Found date for url None
# https://en.wikipedia.org
# Found date for url 2020-07-23
# https://plus.google.com
# Found date for url None
# https://maps.google.com
# Found date for url 2020-07-28
# https://cloudflare.com
# Found date for url 2016-10-24
# https://drive.google.com
# Found date for url None
# https://googleusercontent.com
# Found date for url None
# https://mozilla.org
# Found date for url 2020-08-04
# https://europa.eu
# Found date for url 2008-01-22
# https://accounts.google.com
# Found date for url None
# https://vimeo.com
# Found date for url 2020-03-16
# https://youtu.be
# Found date for url 2020-01-01
# https://sites.google.com
# Found date for url None
# https://amazon.com
# Found date for url None
# https://bbc.co.uk
# Found date for url 2020-08-05
# https://bp.blogspot.com
# Found date for url None
# https://facebook.com
# Found date for url 2020-01-01
# https://istockphoto.com
# Found date for url 2020-08-05
# https://vk.com
# Found date for url None
# https://github.com
# Found date for url 2020-01-01
# https://es.wikipedia.org
# Found date for url 2020-01-01
# https://creativecommons.org
# Found date for url 2020-03-27
# https://medium.com
# Found date for url 2020-08-05
# https://line.me
# Found date for url 2016-01-01
# https://cnn.com
# Found date for url 2014-02-19
# https://wikimedia.org
# Found date for url None
# https://bbc.com
# Found date for url 2020-08-05
# https://www.yahoo.com
# Found date for url 2019-10-18
# https://imdb.com
# Found date for url 2020-08-05
# https://who.int
# Found date for url 2020-08-01
# https://t.me
# Found date for url 2020-07-26
# https://google.es
# Found date for url 2020-01-01
# https://live.com
# Found date for url 2020-01-01
# https://forbes.com
# Found date for url 2020-08-05
# https://mail.ru
# Found date for url 2020-08-05
# https://dailymotion.com
# Found date for url 2020-08-05
# https://google.co.uk
# Found date for url 2020-01-01
# https://theguardian.com
# Found date for url 2020-02-01
# https://google.fr
# Found date for url 2020-01-01
# https://news.google.com
# Found date for url 2020-08-05
# https://google.co.jp
# Found date for url 2020-01-01
# https://msn.com
# Found date for url 2020-01-01
# https://slideshare.net
# Found date for url 2020-08-05
# https://feedburner.com
# Found date for url None
# https://terra.com.br
# Found date for url 2020-08-05
# https://networkadvertising.org
# Found date for url 2020-01-01
# https://jimdofree.com
# Found date for url 2007-01-01
# https://dropbox.com
# Found date for url 2014-01-01
# https://whatsapp.com
# Found date for url 2020-01-01
# https://pt.wikipedia.org
# Found date for url 2020-07-15
# https://gstatic.com
# Found date for url None
# https://mail.google.com
# Found date for url None
# https://nih.gov
# Found date for url 2019-01-01
# https://w3.org
# Found date for url 2020-07-27
# https://hugedomains.com
# Found date for url 2020-05-08
# https://fr.wikipedia.org
# Found date for url 2020-08-04
# https://uol.com.br
# Found date for url 2020-08-05
# https://myspace.com
# Found date for url 2016-04-11
# https://aliexpress.com
# Found date for url 2010-01-01
# https://google.com.br
# Found date for url 2020-01-01
# https://policies.google.com
# Found date for url 2020-08-04
# https://reuters.com
# Found date for url 2020-08-05
# https://photos.google.com
# Found date for url 2020-01-01
# https://nytimes.com
# Found date for url 2020-08-05
# https://globo.com
# Found date for url None
# https://buydomains.com
# Found date for url 2020-01-01
# https://paypal.com
# Found date for url 2020-01-01
# https://developers.google.com
# Found date for url 2020-06-01
# https://google.de
# Found date for url 2020-01-01
# https://twitter.com
# Found date for url None
# https://books.google.com
# Found date for url 2005-01-01
# https://ig.com.br
# Found date for url None
# https://privacyshield.gov
# Found date for url None
# https://nasa.gov
# Found date for url 2011-01-01
# https://abril.com.br
# Found date for url 2020-08-03
# https://steampowered.com
# Found date for url 2020-01-01
# https://bit.ly
# Found date for url 2020-06-26
# https://draft.blogger.com
# Found date for url 2010-05-01
# https://news.yahoo.com
# Found date for url 2020-08-05
# https://wikia.com
# Found date for url 2020-01-01
# https://rakuten.co.jp
# Found date for url 2020-01-01
# https://aboutads.info
# Found date for url 2020-01-01
# https://tools.google.com
# Found date for url 2017-01-01
# https://code.google.com
# Found date for url 2017-01-01
# https://un.org
# Found date for url 2016-01-01
# https://cdc.gov
# Found date for url 2020-08-03
# https://time.com
# Found date for url 2018-04-09
# https://booking.com
# Found date for url 2020-01-01
# https://www.gov.uk
# Found date for url 2020-01-01
# https://get.google.com
# Found date for url 2020-01-01
# https://fandom.com
# Found date for url 2020-08-03
# https://google.it
# Found date for url 2020-01-01
# https://change.org
# Found date for url 2020-07-26
# https://myaccount.google.com
# Found date for url None
# https://ebay.com
# Found date for url 2015-01-02
# https://www.wix.com
# Found date for url 2019-01-01
# https://cpanel.net
# Found date for url 2020-01-01
# https://gravatar.com
# Found date for url 2020-01-01
# https://archive.org
# Found date for url 2005-12-14
# https://independent.co.uk
# Found date for url None
# https://dailymail.co.uk
# Found date for url 2020-08-04
# https://marketingplatform.google.com
# Found date for url None
# https://translate.google.com
# Found date for url 2001-01-01
# https://mirror.co.uk
# Found date for url None
# https://thesun.co.uk
# Found date for url 2020-08-05
# https://plesk.com
# Found date for url None
# https://ft.com
# Found date for url 2020-08-05
# https://cpanel.com
# Found date for url 2020-01-01
# https://hatena.ne.jp
# Found date for url 2020-08-04
# https://ipv4.google.com
# Found date for url 2020-01-01
# https://namecheap.com
# Found date for url 2018-01-01
# https://pinterest.com
# Found date for url 2020-01-01
# https://search.google.com
# Found date for url 2020-01-01
# https://telegraph.co.uk
# Found date for url 2020-08-05
# https://bing.com
# Found date for url 2020-08-05
# https://washingtonpost.com
# Found date for url 2020-07-24
# https://de.wikipedia.org
# Found date for url 2020-01-01
# https://wired.com
# Found date for url 2020-08-05
# https://scribd.com
# Found date for url 2020-03-01
# https://usatoday.com
# Found date for url 2020-08-05
# https://files.wordpress.com
# Found date for url 2019-12-05
# https://mediafire.com
# Found date for url 2020-01-01
# https://themeforest.net
# Found date for url 2020-08-01
# https://android.com
# Found date for url 2000-01-01
# https://telegram.me
# Found date for url 2020-07-26
# https://fb.com
# Found date for url 2020-01-01
# https://picasa.google.com
# Found date for url None
# https://aol.com
# Found date for url 2020-07-01
# https://lefigaro.fr
# Found date for url 2020-08-05
# https://picasaweb.google.com
# Found date for url None
# https://issuu.com
# Found date for url 2019-01-01
# https://wsj.com
# Found date for url None
# https://abcnews.go.com
# Found date for url 2020-01-01
# https://youronlinechoices.com
# Found date for url 2009-01-01
# https://businessinsider.com
# Found date for url 2020-08-05
# https://samsung.com
# Found date for url 2020-08-05
# https://amazon.co.uk
# Found date for url None
# https://foxnews.com
# Found date for url 2020-08-05
# https://sedo.com
# Found date for url 2020-06-01
# https://goo.gl
# Found date for url 2018-03-30
# https://cnet.com
# Found date for url 2020-01-01
# https://google.ru
# Found date for url 2020-01-01
# https://tinyurl.com
# Found date for url 2002-01-01
# https://amazon.co.jp
# Found date for url 2020-07-31
# https://id.wikipedia.org
# Found date for url 2003-11-29
# https://opera.com
# Found date for url 2016-03-10
# https://huffingtonpost.com
# Found date for url None
# https://harvard.edu
# Found date for url 2020-03-11
# https://elpais.com
# Found date for url 2020-08-05
# https://office.com
# Found date for url 2020-08-04
# https://amazon.de
# Found date for url 2020-07-31
# https://ok.ru
# Found date for url 2020-08-04
# https://bloomberg.com
# Found date for url None
# https://wa.me
# Found date for url 2020-01-01
# https://wiley.com
# Found date for url None
# https://indiatimes.com
# Found date for url 2020-07-10
# https://iubenda.com
# Found date for url 2012-03-01
# https://nginx.com
# Found date for url 2020-06-09
# https://cbc.ca
# Found date for url 2019-09-22
# https://surveymonkey.com
# Found date for url 2020-08-05
# https://spotify.com
# Found date for url 2020-01-01
# https://huffpost.com
# Found date for url None
# https://xbox.com
# Found date for url 2020-01-01
# https://academia.edu
# Found date for url 2020-01-01
# https://dell.com
# Found date for url 2020-01-01
# https://icann.org
# Found date for url 2020-07-28
# https://twitch.tv
# Found date for url None
# https://a8.net
# Found date for url 2020-07-10
# https://rambler.ru
# Found date for url 2020-08-05
# https://stanford.edu
# Found date for url None
# https://wikihow.com
# Found date for url 2019-01-01
# https://eventbrite.com
# Found date for url 2020-08-04
# https://disney.com
# Found date for url 2016-05-13
# https://amazon.it
# Found date for url None
# https://welt.de
# Found date for url 2020-08-05
# https://4shared.com
# Found date for url None
# https://pl.wikipedia.org
# Found date for url 2020-08-05
# https://sciencedaily.com
# Found date for url None
# https://sputniknews.com
# Found date for url 2020-08-05
# https://bp1.blogger.com
# Found date for url None
# https://theatlantic.com
# Found date for url 2020-08-04
# https://loc.gov
# Found date for url 2020-08-01
# https://deezer.com
# Found date for url None
# https://lemonde.fr
# Found date for url 2020-08-05
# https://alibaba.com
# Found date for url 2017-09-11
# https://mega.nz
# Found date for url None
# https://usnews.com
# Found date for url None
# https://worldbank.org
# Found date for url None
# https://goodreads.com
# Found date for url 2020-01-01
# https://xinhuanet.com
# Found date for url None
# https://imageshack.us
# Found date for url 2020-01-01
# https://photobucket.com
# Found date for url 2020-01-01
# https://imageshack.com
# Found date for url 2020-01-01
# https://orkut.com.br
# Found date for url 2019-01-01
# https://qq.com
# Found date for url 2018-10-10
# https://ikea.com
# Found date for url None
# https://netflix.com
# Found date for url 2018-11-26
# https://storage.googleapis.com
# Found date for url None
# https://lg.com
# Found date for url 2018-09-28
# https://ea.com
# Found date for url 2020-08-03
# https://cambridge.org
# Found date for url None
# https://php.net
# Found date for url 2020-07-23
# https://disqus.com
# Found date for url None
# https://news.com.au
# Found date for url 2020-08-05
# https://dan.com
# Found date for url None
# https://nikkei.com
# Found date for url 2020-06-08
# https://metro.co.uk
# Found date for url 2020-08-05
# https://forms.gle
# Found date for url None
# https://cornell.edu
# Found date for url 2020-02-09
# https://gofundme.com
# Found date for url 2017-01-01
# https://ytimg.com
# Found date for url None
# https://trustpilot.com
# Found date for url 2020-08-05
# https://biglobe.ne.jp
# Found date for url 2020-07-20
# https://hollywoodreporter.com
# Found date for url 2020-08-05
# https://yale.edu
# Found date for url 2020-08-04
# https://abc.es
# Found date for url 2020-08-05
# https://shutterstock.com
# Found date for url None
# https://abc.net.au
# Found date for url 2020-08-01
# https://ign.com
# Found date for url None
# https://walmart.com
# Found date for url 2020-08-05
# https://goo.ne.jp
# Found date for url 2020-08-04
# https://bandcamp.com
# Found date for url 2020-08-04
# https://m.wikipedia.org
# Found date for url None
# https://instagram.com
# Found date for url 2018-01-01
# https://depositfiles.com
# Found date for url 2006-01-01
# https://wp.com
# Found date for url 2019-12-05
# https://stackoverflow.com
# Found date for url 2020-01-01
# https://oup.com
# Found date for url 2020-01-01
# https://amazon.es
# Found date for url 2020-07-31
# https://ietf.org
# Found date for url 2020-07-28
# https://hp.com
# Found date for url 2020-07-23
# https://000webhost.com
# Found date for url None
# https://secureserver.net
# Found date for url None
# https://photos1.blogger.com
# Found date for url None
# https://researchgate.net
# Found date for url 2020-01-01
# https://techcrunch.com
# Found date for url 2020-08-05
# https://nhk.or.jp
# Found date for url None
# https://buzzfeed.com
# Found date for url 2020-07-31
# https://britannica.com
# Found date for url 2020-01-01
# https://yahoo.co.jp
# Found date for url 2020-08-05
# https://unesco.org
# Found date for url None
# https://over-blog-kiwi.com
# Found date for url 2020-06-06
# https://google.com.tw
# Found date for url 2020-01-01
# https://list-manage.com
# Found date for url None
# https://ted.com
# Found date for url 2016-06-13
# https://npr.org
# Found date for url 2020-08-05
# https://kickstarter.com
# Found date for url 2020-01-01
# https://playstation.com
# Found date for url 2020-06-11
# https://columbia.edu
# Found date for url 2020-01-01
# https://google.nl
# Found date for url 2020-01-01
# https://ovh.com
# Found date for url 2014-03-14
# https://groups.google.com
# Found date for url None
# https://my.yahoo.com
# Found date for url 2020-08-05
# https://nokia.com
# Found date for url 2020-06-27
# https://urbandictionary.com
# Found date for url 2019-01-16
# https://psychologytoday.com
# Found date for url None
# https://bloglovin.com
# Found date for url None
# https://instructables.com
# Found date for url 2020-01-01
# https://umich.edu
# Found date for url 2020-08-01
# https://latimes.com
# Found date for url None
# https://netvibes.com
# Found date for url 2020-01-01
# https://economist.com
# Found date for url 2020-08-05
# https://ovh.net
# Found date for url 2016-03-08
# https://newsweek.com
# Found date for url None
# https://ibm.com
# Found date for url 2020-08-03
# https://ggpht.com
# Found date for url None
# https://pixabay.com
# Found date for url None
# https://yandex.ru
# Found date for url 2020-08-05
# https://dw.com
# Found date for url 2020-01-01
# https://pexels.com
# Found date for url None
# https://addtoany.com
# Found date for url 2006-01-01
# https://fastcompany.com
# Found date for url 2000-01-01
# https://apache.org
# Found date for url 2020-01-01
# https://quora.com
# Found date for url 2020-01-01
# https://nydailynews.com
# Found date for url None
# https://gizmodo.com
# Found date for url 2007-02-04
# https://hm.com
# Found date for url None
# https://weibo.com
# Found date for url 2020-08-05
# https://nypost.com
# Found date for url 2020-08-05
# https://addthis.com
# Found date for url 2020-01-01
# https://mozilla.com
# Found date for url 2020-08-04
# https://noaa.gov
# Found date for url None
# https://nginx.org
# Found date for url 2020-07-07
# https://bp2.blogger.com
# Found date for url None
# https://google.co.in
# Found date for url 2020-01-01
# https://princeton.edu
# Found date for url 2020-07-31
# https://scoop.it
# Found date for url 2016-04-01
# https://windowsphone.com
# Found date for url 2020-05-08
# https://guardian.co.uk
# Found date for url 2020-02-01
# https://nvidia.com
# Found date for url None
# https://sapo.pt
# Found date for url 2020-08-05
# https://ria.ru
# Found date for url 2020-08-04
# https://vice.com
# Found date for url 2020-08-05
# https://gnu.org
# Found date for url 2020-07-31
# https://cbsnews.com
# Found date for url 2018-08-14
# https://www.livejournal.com
# Found date for url 2018-01-01
# https://yelp.com
# Found date for url 2019-09-30
# https://webmd.com
# Found date for url None
# https://ovh.co.uk
# Found date for url 2014-03-14
# https://amazon.fr
# Found date for url 2020-07-31
# https://naver.jp
# Found date for url 2020-06-08
# https://cisco.com
# Found date for url 2020-08-05
# https://tes.com
# Found date for url 2020-01-01
# https://ja.wikipedia.org
# Found date for url 2020-07-11
# https://express.co.uk
# Found date for url 2020-08-05
# https://asus.com
# Found date for url None
# https://marriott.com
# Found date for url 2020-06-08
# https://bt.com
# Found date for url 2020-01-01
# https://tripadvisor.com
# Found date for url 2020-01-01
# https://digg.com
# Found date for url 2020-08-05
# https://bitly.com
# Found date for url 2020-06-26
# https://pbs.org
# Found date for url 2020-07-01
# https://oracle.com
# Found date for url 2020-06-24
# https://espn.com
# Found date for url 2020-08-05
# https://doubleclick.net
# Found date for url None
# https://naver.com
# Found date for url 2020-07-23
# https://sciencemag.org
# Found date for url 2020-08-05
# https://google.co.id
# Found date for url 2020-01-01
# https://shopify.com
# Found date for url 2019-08-08
# https://soundcloud.com
# Found date for url None
# https://google.pl
# Found date for url 2020-01-01
# https://blackberry.com
# Found date for url 2020-08-05
# https://standard.co.uk
# Found date for url 2020-08-05
# https://t.co
# Found date for url None
# https://mit.edu
# Found date for url 2020-08-05
# https://nbcnews.com
# Found date for url 2020-07-15
# https://sciencedirect.com
# Found date for url None
# https://vox.com
# Found date for url 2020-04-08
# https://engadget.com
# Found date for url 2020-08-01
# https://mashable.com
# Found date for url 2020-01-01
# https://box.com
# Found date for url 2016-03-19
# https://ox.ac.uk
# Found date for url 2020-08-04
# https://gmail.com
# Found date for url None
# https://smh.com.au
# Found date for url 2020-06-08
# https://mystrikingly.com
# Found date for url 2013-09-29
# https://thetimes.co.uk
# Found date for url 2020-08-05
# https://channel4.com
# Found date for url None
# https://it.wikipedia.org
# Found date for url 2020-05-06
# https://www.wikipedia.org
# Found date for url None
# https://e-recht24.de
# Found date for url 2020-07-28
# https://berkeley.edu
# Found date for url 2020-07-24
# https://sfgate.com
# Found date for url 2020-08-05
# https://target.com
# Found date for url 2020-07-29
# https://www.weebly.com
# Found date for url 2019-01-01
# https://zendesk.com
# Found date for url 2020-06-12
# https://adssettings.google.com
# Found date for url 2020-01-01
# https://utexas.edu
# Found date for url 2020-07-29
# https://washington.edu
# Found date for url 2020-07-30
# https://akamaihd.net
# Found date for url None
# https://whitehouse.gov
# Found date for url 2020-08-05
# https://nationalgeographic.com
# Found date for url 2020-08-04
# https://spiegel.de
# Found date for url 2020-06-08
# https://rapidshare.com
# Found date for url None
# https://finance.yahoo.com
# Found date for url 2020-08-05
# https://detik.com
# Found date for url 2020-08-04
# https://elmundo.es
# Found date for url 2020-08-05
# https://rtve.es
# Found date for url None
# https://rt.com
# Found date for url 2020-07-06
# https://mysql.com
# Found date for url 2020-06-04
# https://ru.wikipedia.org
# Found date for url 2004-04-27
# https://nature.com
# Found date for url 2020-07-30
# https://cnbc.com
# Found date for url 2018-02-26
# https://godaddy.com
# Found date for url None
# https://bp0.blogger.com
# Found date for url None
# https://www.over-blog.com
# Found date for url 2020-06-06
# https://sendspace.com
# Found date for url 2005-01-01
# https://fifa.com
# Found date for url 2015-06-14
# https://theverge.com
# Found date for url 2020-08-05
# https://about.com
# Found date for url 2010-07-03
# https://yadi.sk
# Found date for url 2019-01-01
# https://googleblog.com
# Found date for url 2018-05-16
# https://google.ca
# Found date for url 2020-01-01
# https://variety.com
# Found date for url 2020-06-08
# https://so-net.ne.jp
# Found date for url 2010-01-01
# https://prestashop.com
# Found date for url 2020-07-28
# https://slate.com
# Found date for url 2020-02-26
# https://asahi.com
# Found date for url 2020-08-05
# https://businesswire.com
# Found date for url 2020-08-05
# https://discovery.com
# Found date for url None
# https://autodesk.com
# Found date for url 2020-01-01
# https://zeit.de
# Found date for url 2020-08-05
# https://sakura.ne.jp
# Found date for url 2020-02-28
# https://thestar.com
# Found date for url 2020-06-24
# https://consumerreports.org
# Found date for url 2020-08-01
# https://dreniq.com
# Found date for url 2020-07-22
# https://statista.com
# Found date for url 2020-01-01
# https://interia.pl
# Found date for url 2020-08-01
# https://politico.com
# Found date for url 2020-07-30
# https://20minutos.es
# Found date for url 2020-06-08
# https://techradar.com
# Found date for url 2020-08-05
# https://merriam-webster.com
# Found date for url 2020-08-05
# https://corriere.it
# Found date for url 2020-08-05
# https://ebay.co.uk
# Found date for url 2020-01-01
# https://outlook.com
# Found date for url 2020-01-01
# https://gutenberg.org
# Found date for url 2020-01-01
# https://fortune.com
# Found date for url 2020-08-05
# https://thehill.com
# Found date for url 2020-08-05
# https://mercurynews.com
# Found date for url 2020-08-05
# https://indiegogo.com
# Found date for url 2020-08-01
# https://foursquare.com
# Found date for url 2020-01-01
# https://axs.com
# Found date for url None
# https://pcmag.com
# Found date for url 2020-01-01
# https://weforum.org
# Found date for url 2020-08-05
# https://house.gov
# Found date for url 2020-07-27
# https://cmu.edu
# Found date for url 2020-01-01
# https://airbnb.com
# Found date for url 2020-01-01
# https://debian.org
# Found date for url 2020-08-05
# https://behance.net
# Found date for url 2020-08-05
# https://teamviewer.com
# Found date for url 2020-07-29
# https://www.nhs.uk
# Found date for url 2020-07-27
# https://disney.go.com
# Found date for url None
# https://archives.gov
# Found date for url 2019-01-01
# https://ndtv.com
# Found date for url 2020-08-01
# https://mail.yahoo.com
# Found date for url None
# https://greenpeace.org
# Found date for url None
# https://cbslocal.com
# Found date for url 2020-01-01
# https://intel.com
# Found date for url 2020-07-22
# https://mhlw.go.jp
# Found date for url None
# https://csmonitor.com
# Found date for url 2020-08-01
# https://newscientist.com
# Found date for url 2020-08-05
# https://marketwatch.com
# Found date for url 2020-08-05
# https://sedoparking.com
# Found date for url None
# https://dribbble.com
# Found date for url 2020-01-01
# https://megaupload.com
# Found date for url None
# https://usgs.gov
# Found date for url 2020-01-01
# https://inc.com
# Found date for url 2020-08-04
# https://stuff.co.nz
# Found date for url 2020-06-01
# https://wiktionary.org
# Found date for url None
# https://amazon.ca
# Found date for url None
# https://offset.com
# Found date for url 2020-01-01
# https://thenextweb.com
# Found date for url None
# https://snapchat.com
# Found date for url None
# https://viagens.com.br
# Found date for url 2019-01-01
# https://amazon.in
# Found date for url 2020-07-31
# https://newyorker.com
# Found date for url 2020-08-03
# https://rottentomatoes.com
# Found date for url 2019-08-20
# https://ameblo.jp
# Found date for url 2020-05-19
# https://prnewswire.com
# Found date for url 2020-08-04
# https://thedailybeast.com
# Found date for url 2020-01-01
# https://oreilly.com
# Found date for url 2020-08-05
# https://ieee.org
# Found date for url 2020-01-01
# https://www.canalblog.com
# Found date for url 2020-02-08
# https://blog.fc2.com
# Found date for url 2020-05-08
# https://discord.gg
# Found date for url None
# https://xing.com
# Found date for url None
# https://search.yahoo.com
# Found date for url None
# https://zdnet.com
# Found date for url 2015-03-19
# https://rediff.com
# Found date for url 2020-01-01
# https://lycos.com
# Found date for url 2020-01-01
# https://adweek.com
# Found date for url 2017-01-25
# https://tabelog.com
# Found date for url 2020-01-01
# https://irs.gov
# Found date for url 2018-06-01
# https://answers.com
# Found date for url 2019-11-04
# https://livescience.com
# Found date for url 2020-08-05
# https://steamcommunity.com
# Found date for url None
# https://epa.gov
# Found date for url 2020-08-01
# https://answers.yahoo.com
# Found date for url 2020-08-05
# https://narod.ru
# Found date for url 2019-01-01
# https://about.me
# Found date for url 2020-01-01
# https://redhat.com
# Found date for url 2020-01-01
# https://medicalnewstoday.com
# Found date for url 2020-03-06
# https://daum.net
# Found date for url 2020-06-08
# https://allaboutcookies.org
# Found date for url None
# https://kinja.com
# Found date for url None
# https://coursera.org
# Found date for url 2020-01-01
# https://springer.com
# Found date for url 2020-01-01
# https://feedproxy.google.com
# Found date for url None
# https://cia.gov
# Found date for url 2020-05-12
# https://espn.go.com
# Found date for url 2020-08-05
# https://ubuntu.com
# Found date for url 2020-01-01
# https://history.com
# Found date for url 2020-06-22
# https://parallels.com
# Found date for url 2020-07-31
# https://calameo.com
# Found date for url None
# https://prezi.com
# Found date for url 2020-01-01
# https://usc.edu
# Found date for url 2020-01-01
# https://scientificamerican.com
# Found date for url 2020-07-13
# https://psu.edu
# Found date for url 2020-07-30
# https://lifehacker.com
# Found date for url 2020-08-05
# https://ca.gov
# Found date for url 2019-01-01
# https://digitaltrends.com
# Found date for url 2020-08-05
# https://liveinternet.ru
# Found date for url 1998-01-01
# https://gesetze-im-internet.de
# Found date for url None
# https://imgur.com
# Found date for url 2020-01-01
# https://chicagotribune.com
# Found date for url 2020-08-05
# https://vchecks.me
# Found date for url None
# https://cocolog-nifty.com
# Found date for url None
# https://state.gov
# Found date for url 2020-08-05
# https://gamespot.com
# Found date for url 2020-08-05
# https://storage.canalblog.com
# Found date for url None
# https://eff.org
# Found date for url 2020-08-05

# %%
data
# Out:
#      Rank            Root Domain Linking Root Domains  Domain Authority  \
# 0       1              apple.com            4,606,834               100
# 1       2         www.google.com           12,130,886               100
# 2       3            youtube.com           17,792,956               100
# 3       4          microsoft.com            4,544,029                99
# 4       5        play.google.com            2,383,583                99
# ..    ...                    ...                  ...               ...
# 495   496      cocolog-nifty.com              183,054                92
# 496   497              state.gov              265,728                92
# 497   498           gamespot.com              180,403                92
# 498   499  storage.canalblog.com              275,403                92
# 499   500                eff.org              137,613                92
#
#     Publish Date
# 0     2020-01-01
# 1     2020-01-01
# 2     2020-01-01
# 3     2020-08-04
# 4     2020-07-26
# ..           ...
# 495         None
# 496   2020-08-05
# 497   2020-08-05
# 498         None
# 499   2020-08-05
#
# [500 rows x 5 columns]

# %%
print(data)
# Out:
#      Rank            Root Domain Linking Root Domains  Domain Authority  \
# 0       1              apple.com            4,606,834               100
# 1       2         www.google.com           12,130,886               100
# 2       3            youtube.com           17,792,956               100
# 3       4          microsoft.com            4,544,029                99
# 4       5        play.google.com            2,383,583                99
# ..    ...                    ...                  ...               ...
# 495   496      cocolog-nifty.com              183,054                92
# 496   497              state.gov              265,728                92
# 497   498           gamespot.com              180,403                92
# 498   499  storage.canalblog.com              275,403                92
# 499   500                eff.org              137,613                92
#
#     Publish Date
# 0     2020-01-01
# 1     2020-01-01
# 2     2020-01-01
# 3     2020-08-04
# 4     2020-07-26
# ..           ...
# 495         None
# 496   2020-08-05
# 497   2020-08-05
# 498         None
# 499   2020-08-05
#
# [500 rows x 5 columns]
